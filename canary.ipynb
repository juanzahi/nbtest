# %% [markdown]
# # nb canary (markdown cell)
# <base href="//nb-canary-base.invalid/">
# <script src="/nb-canary-script.js"></script>
# <script>window.NB_CANARY_INLINE=1</script>
# <iframe src="https://example.com/nb-canary-iframe"></iframe>
# <img src=x onerror="window.NB_CANARY_ONERROR=1">
# <svg><script>window.NB_CANARY_SVG=1</script></svg>
# <form action="https://nb-canary-form.invalid/x"><input name=q></form>
# <object data="https://nb-canary-object.invalid/x"></object>
# <meta http-equiv="refresh" content="0;url=//nb-canary-meta.invalid/">
# <link rel="import" href="//nb-canary-link.invalid/">
# <style>body{background:url(//nb-canary-style.invalid/x)}</style>
# <a href="javascript:window.NB_CANARY_HREF=1">x</a>

# %%
print('x')
# Out:
# <base href="//nb-canary-base.invalid/">
# <script src="/nb-canary-script.js"></script>
# <script>window.NB_CANARY_INLINE=1</script>
# <iframe src="https://example.com/nb-canary-iframe"></iframe>
# <img src=x onerror="window.NB_CANARY_ONERROR=1">
# <svg><script>window.NB_CANARY_SVG=1</script></svg>
# <form action="https://nb-canary-form.invalid/x"><input name=q></form>
# <object data="https://nb-canary-object.invalid/x"></object>
# <meta http-equiv="refresh" content="0;url=//nb-canary-meta.invalid/">
# <link rel="import" href="//nb-canary-link.invalid/">
# <style>body{background:url(//nb-canary-style.invalid/x)}</style>
# <a href="javascript:window.NB_CANARY_HREF=1">x</a>
# x
