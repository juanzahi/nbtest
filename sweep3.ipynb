# %%
# L-pos
# Out:
# MARKER::L-pos::END
# $\unicode[x;position:fixed](x30)$ s3lpos

# %%
# L-top
# Out:
# MARKER::L-top::END
# $\unicode[x;top:0](x30)$ s3ltop

# %%
# L-left
# Out:
# MARKER::L-left::END
# $\unicode[x;left:0](x30)$ s3lleft

# %%
# L-wh
# Out:
# MARKER::L-wh::END
# $\unicode[x;width:100vw;height:100vh](x30)$ s3lwh

# %%
# L-z
# Out:
# MARKER::L-z::END
# $\unicode[x;z-index:99999](x30)$ s3lz

# %%
# L-bg
# Out:
# MARKER::L-bg::END
# $\unicode[x;background:red](x30)$ s3lbg

# %%
# L-bgurl
# Out:
# MARKER::L-bgurl::END
# $\unicode[x;background:url(//s3-bgurl.invalid/)](x30)$ s3lbgurl

# %%
# L-op
# Out:
# MARKER::L-op::END
# $\unicode[x;opacity:0.5](x30)$ s3lop

# %%
# L-tf
# Out:
# MARKER::L-tf::END
# $\unicode[x;transform:scale(9)](x30)$ s3ltf

# %%
# L-disp
# Out:
# MARKER::L-disp::END
# $\unicode[x;display:block](x30)$ s3ldisp

# %%
# L-col
# Out:
# MARKER::L-col::END
# $\unicode[x;color:lime](x30)$ s3lcol

# %%
# L-href
# Out:
# MARKER::L-href::END
# \href{//s3-href.invalid/}{s3lhref}

# %%
# L-raw
# Out:
# MARKER::L-raw::END
# <img src=x onerror=window.S3RAW=1> s3lraw

# %%
# L-style
# Out:
# MARKER::L-style::END
# <style>/*s3lstyle*/</style> s3lstyle

# %%
# S-script
# Out:
# MARKER::S-script::END

# %%
# S-onload
# Out:
# MARKER::S-onload::END

# %%
# S-fo
# Out:
# MARKER::S-fo::END

# %%
# S-anim
# Out:
# MARKER::S-anim::END

# %%
# S-js
# Out:
# MARKER::S-js::END

# %%
# S-json
# Out:
# MARKER::S-json::END

# %%
# S-wstate
# Out:
# MARKER::S-wstate::END

# %%
# S-wview
# Out:
# MARKER::S-wview::END

# %%
# S-md
# Out:
# MARKER::S-md::END
# <svg><animate attributeName="href" values="javascript:1"/></svg> s3md

# %% [raw]
# MARKER::RAW::END <img src=x onerror="window.S3RAWCELL=1"> s3rawcell

# %%
# MARKER::TAGS::END
