# %%
# T000
# Out:
# <span>T000</span><base href="//enum-T000.invalid/">

# %%
# T001
# Out:
# <span>T001</span><BASE HREF="//enum-T001.invalid/">

# %%
# T002
# Out:
# <span>T002</span><base/href="//enum-T002.invalid/">

# %%
# T003
# Out:
# <span>T003</span><base href=//enum-T003.invalid/>

# %%
# T004
# Out:
# <span>T004</span><base	href="//enum-T004.invalid/">

# %%
# T005
# Out:
# <span>T005</span><base
# href="//enum-T005.invalid/">

# %%
# T006
# Out:
# <span>T006</span><svg><base href="//enum-T006.invalid/"></svg>

# %%
# T007
# Out:
# <span>T007</span><math><base href="//enum-T007.invalid/"></math>

# %%
# T008
# Out:
# <span>T008</span><details><base href="//enum-T008.invalid/"></details>

# %%
# T009
# Out:
# <span>T009</span><template><base href="//enum-T009.invalid/"></template>

# %%
# T010
# Out:
# <span>T010</span><noscript><base href="//enum-T010.invalid/"></noscript>

# %%
# T011
# Out:
# <span>T011</span><svg><foreignObject><base href="//enum-T011.invalid/"></foreignObject></svg>

# %%
# T012
# Out:
# <span>T012</span><p><style></style><base href="//enum-T012.invalid/">

# %%
# T013
# Out:
# <span>T013</span><a><base href="//enum-T013.invalid/"></a>

# %%
# T014
# Out:
# <span>T014</span><img src=x><base href="//enum-T014.invalid/">

# %%
# T015
# Out:
# <span>T015</span><!--><base href="//enum-T015.invalid/">-->

# %%
# T016
# Out:
# <span>T016</span><svg><p><style><base href="//enum-T016.invalid/">

# %%
# T017
# Out:
# <span>T017</span><xml:base href="//enum-T017.invalid/">

# %%
# T018
# Out:
# <span>T018</span><meta http-equiv="Content-Base" content="//enum-T018.invalid/">

# %%
# T019
# Out:
# <span>T019</span><div xml:base="//enum-T019.invalid/">x</div>

# %%
# T020
# Out:
# <span>T020</span><img onload="window.ENUM_ONLOAD=1" src=x tabindex=1 autofocus>z</img>

# %%
# T021
# Out:
# <span>T021</span><img onanimationstart="window.ENUM_ONANIMATIONSTART=1" src=x tabindex=1 autofocus>z</img>

# %%
# T022
# Out:
# <span>T022</span><img onbeforetoggle="window.ENUM_ONBEFORETOGGLE=1" src=x tabindex=1 autofocus>z</img>

# %%
# T023
# Out:
# <span>T023</span><svg onload="window.ENUM_ONLOAD=1" src=x tabindex=1 autofocus>z</svg>

# %%
# T024
# Out:
# <span>T024</span><svg onbegin="window.ENUM_ONBEGIN=1" src=x tabindex=1 autofocus>z</svg>

# %%
# T025
# Out:
# <span>T025</span><a onfocus="window.ENUM_ONFOCUS=1" src=x tabindex=1 autofocus>z</a>

# %%
# T026
# Out:
# <span>T026</span><a onpointerover="window.ENUM_ONPOINTEROVER=1" src=x tabindex=1 autofocus>z</a>

# %%
# T027
# Out:
# <span>T027</span><details ontoggle="window.ENUM_ONTOGGLE=1" src=x tabindex=1 autofocus>z</details>

# %%
# T028
# Out:
# <span>T028</span><body onload="window.ENUM_ONLOAD=1" src=x tabindex=1 autofocus>z</body>

# %%
# T029
# Out:
# <span>T029</span><video onloadstart="window.ENUM_ONLOADSTART=1" src=x tabindex=1 autofocus>z</video>

# %%
# T030
# Out:
# <span>T030</span><audio onplay="window.ENUM_ONPLAY=1" src=x tabindex=1 autofocus>z</audio>

# %%
# T031
# Out:
# <span>T031</span><form onsubmit="window.ENUM_ONSUBMIT=1" src=x tabindex=1 autofocus>z</form>

# %%
# T032
# Out:
# <span>T032</span><input onfocus="window.ENUM_ONFOCUS=1" src=x tabindex=1 autofocus>z</input>

# %%
# T033
# Out:
# <span>T033</span><marquee onstart="window.ENUM_ONSTART=1" src=x tabindex=1 autofocus>z</marquee>

# %%
# T034
# Out:
# <span>T034</span><object onerror="window.ENUM_ONERROR=1" src=x tabindex=1 autofocus>z</object>

# %%
# T035
# Out:
# <span>T035</span><svg><use href="data:image/svg+xml,&lt;svg id=x xmlns='http://www.w3.org/2000/svg'&gt;&lt;/svg&gt;#x"/></svg>

# %%
# T036
# Out:
# <span>T036</span><svg><animate attributeName="href" to="javascript:window.ENUM_ANIM=1"/><a><text>x</text></a></svg>

# %%
# T037
# Out:
# <span>T037</span><svg><set attributeName="onload" to="window.ENUM_SET=1"/></svg>

# %%
# T038
# Out:
# <span>T038</span><svg><script href="//enum-T038.invalid/"/></svg>

# %%
# T039
# Out:
# <span>T039</span><svg><handler>window.ENUM_H=1</handler></svg>

# %%
# T040
# Out:
# <span>T040</span><svg><foreignObject><iframe src="//enum-T040.invalid/"></iframe></foreignObject></svg>

# %%
# T041
# Out:
# <span>T041</span><svg xmlns:xlink="http://www.w3.org/1999/xlink"><a xlink:href="javascript:1"><text>x</text></a></svg>

# %%
# T042
# Out:
# <span>T042</span><img srcset="//enum-T042.invalid/x 1x">

# %%
# T043
# Out:
# <span>T043</span><img src="//enum-T043.invalid/">

# %%
# T044
# Out:
# <span>T044</span><a href="//enum-T044.invalid/">x</a>

# %%
# T045
# Out:
# <span>T045</span><form action="//enum-T045.invalid/"><input name=q></form>

# %%
# T046
# Out:
# <span>T046</span><button formaction="//enum-T046.invalid/">x</button>

# %%
# T047
# Out:
# <span>T047</span><video poster="//enum-T047.invalid/"></video>

# %%
# T048
# Out:
# <span>T048</span><object data="//enum-T048.invalid/"></object>

# %%
# T049
# Out:
# <span>T049</span><embed src="//enum-T049.invalid/">

# %%
# T050
# Out:
# <span>T050</span><iframe src="//enum-T050.invalid/"></iframe>

# %%
# T051
# Out:
# <span>T051</span><link rel=stylesheet href="//enum-T051.invalid/">

# %%
# T052
# Out:
# <span>T052</span><link rel=preload as=script href="//enum-T052.invalid/">

# %%
# T053
# Out:
# <span>T053</span><meta http-equiv=refresh content="0;url=//enum-T053.invalid/">

# %%
# T054
# Out:
# <span>T054</span><div style="background:url(//enum-T054.invalid/)">x</div>

# %%
# T055
# Out:
# <span>T055</span><style>@import url(//enum-T055.invalid/);</style>

# %%
# T056
# Out:
# <span>T056</span><div style="behavior:url(//enum-T056.invalid/)">x</div>

# %%
# T057
# Out:
# <span>T057</span><img style="content:url(//enum-T057.invalid/)">

# %%
# T058
# Out:
# <span>T058</span><noscript><p title="&lt;/noscript&gt;&lt;base href=//enum-T058.invalid/&gt;">

# %%
# T059
# Out:
# <span>T059</span><svg></p><style><a id="</style><base href=//enum-T059.invalid/>">

# %%
# T060
# Out:
# <span>T060</span><form><math><mtext></form><form><mglyph><style></math><base href="//enum-T060.invalid/">

# %%
# T061
# Out:
# <span>T061</span><table><caption><svg><desc><![CDATA[</desc><base href="//enum-T061.invalid/">]]>

# %%
# T062
# Out:
# <span>T062</span><a title="</a><base href=//enum-T062.invalid/>">x</a>
