# %%
# Q1A
# Out:
# MARKER::Q1A::END
# <base href="//sw2-q1a.invalid/">

# %%
# Q1B
# Out:
# MARKER::Q1B::END
# <BASE HREF="//sw2-q1b.invalid/">

# %%
# Q1C
# Out:
# MARKER::Q1C::END
# <base href="https://sw2-q1c.invalid/">

# %%
# Q1D
# Out:
# MARKER::Q1D::END
# <div><base href="//sw2-q1d.invalid/"></div>

# %%
# Q1E
# Out:
# MARKER::Q1E::END
# <svg><base href="//sw2-q1e.invalid/"></svg>

# %%
# Q2A
# Out:
# MARKER::Q2A::END
# <svg><a><animate attributeName="href" values="javascript:window.SW2A=1" begin="0s"/><text x="10" y="20">sw2q2a</text></a></svg>

# %%
# Q2B
# Out:
# MARKER::Q2B::END
# <svg><a><set attributeName="href" to="javascript:window.SW2B=1"/><text x="10" y="20">sw2q2b</text></a></svg>

# %%
# Q2C
# Out:
# MARKER::Q2C::END
# <svg><a><animate attributeName="xlink:href" values="javascript:window.SW2C=1" begin="0s"/><text>sw2q2c</text></a></svg>

# %%
# Q3A
# Out:
# MARKER::Q3A::END
# \href{javascript:window.SW3A=1}{sw2q3a}

# %%
# Q3B
# Out:
# MARKER::Q3B::END
# $\unicode[x;color:red](x30)$ sw2q3b

# %%
# Q3C
# Out:
# MARKER::Q3C::END

# %%
# Q3D
# Out:
# MARKER::Q3D::END
# <base href="//sw2-q3d.invalid/">

# %%
# Q4-style
# Out:
# MARKER::Q4-style::END
# <style>/*sw2-style*/</style>

# %%
# Q4-animate
# Out:
# MARKER::Q4-animate::END
# <svg><animate id="sw2-animate"/></svg>

# %%
# Q4-set
# Out:
# MARKER::Q4-set::END
# <svg><set id="sw2-set"/></svg>

# %%
# Q4-use
# Out:
# MARKER::Q4-use::END
# <svg><use id="sw2-use" href="#x"/></svg>

# %%
# Q4-foreignObject
# Out:
# MARKER::Q4-foreignObject::END
# <svg><foreignObject id="sw2-fo">x</foreignObject></svg>

# %%
# Q4-math
# Out:
# MARKER::Q4-math::END
# <math id="sw2-math"><mtext>x</mtext></math>

# %%
# Q4-form
# Out:
# MARKER::Q4-form::END
# <form id="sw2-form"><input name=q></form>

# %%
# Q4-iframe
# Out:
# MARKER::Q4-iframe::END
# <iframe id="sw2-iframe" src="//sw2-iframe.invalid/"></iframe>

# %%
# Q4-object
# Out:
# MARKER::Q4-object::END
# <object id="sw2-object" data="//sw2-object.invalid/"></object>

# %%
# Q4-template
# Out:
# MARKER::Q4-template::END
# <template id="sw2-template">x</template>

# %%
# Q4-noscript
# Out:
# MARKER::Q4-noscript::END
# <noscript id="sw2-noscript">x</noscript>

# %%
# Q4-link
# Out:
# MARKER::Q4-link::END
# <link id="sw2-link" rel="stylesheet" href="//sw2-link.invalid/">

# %%
# Q4-meta
# Out:
# MARKER::Q4-meta::END
# <meta id="sw2-meta" http-equiv="refresh" content="0;url=//sw2-meta.invalid/">

# %%
# Q4-video
# Out:
# MARKER::Q4-video::END
# <video id="sw2-video" src="//sw2-video.invalid/"></video>

# %%
# Q4-details
# Out:
# MARKER::Q4-details::END
# <details id="sw2-details"><summary>x</summary></details>

# %%
# Q4-picture
# Out:
# MARKER::Q4-picture::END
# <picture id="sw2-picture"><source srcset="//sw2-picture.invalid/"></picture>
